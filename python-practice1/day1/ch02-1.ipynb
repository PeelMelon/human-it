# %%
print("hello world")

a=1
b=4
print(a+b)

a = "python"
print(a)

def add(a, b):
        return a+b

print(add(3,4))

print("Hello world")

a = 0o177
print(a)
a = 0o2
print(a)
a = 0o7
print(a)

a = 0x8ff
b = 0xabc
print(a)
print(b)

a = 3
b = 4
print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a ** b)

print(7 % 3)
print(3 % 7)
print(7 / 4)
print(7 // 4)

a = 1
a = a + 1
print(a)

a = 1
a += 1
print(a)

a = 1
a -= 1
print(a)

a = 16
a %= 5


a = 18
a **= 2
print(a)
# Out:
# hello world
# 5
# python
# 7
# Hello world
# 127
# 2
# 7
# 2303
# 2748
# 7
# -1
# 12
# 0.75
# 81
# 1
# 3
# 1.75
# 1
# 2
# 2
# 0
# 324
